# %%
from sportsipy.nfl.boxscore import Boxscores        # Retrieve a dictionary which contains a major game data of all games being played on a particular day.
from sportsipy.nfl.boxscore import Boxscore         # Detailed information about the final statistics for a game.
import pandas as pd
import sys


def main():

    if(False):
        # Create Boxscores Object for the 2023 season weeks 1 - 8
        week1thru8_BOX = Boxscores(1, 2023, 8)
        print("Boxscore Class: ")
        print(week1thru8_BOX)

        # Print dictionary of all games played within the Boxscores' scope (Weeks 1 - 8)
        # Format {Week: [{Array of dictionaries that contain game info}]}
        # print("\nGames: ")
        # print(week1thru8_BOX.games)

        # Get week 1, game 1's URI
        week1_game1_URI = week1thru8_BOX.games['1-2023'][0]['boxscore']
        print("\nGame 0 URI: ")
        print(week1_game1_URI)

        # Create Detailed Boxscore object using URI
        week1_game1_BOX = Boxscore(week1_game1_URI)

        # Create dataframe out of week 1, game 1's boxscore
        week1_game1_DF = week1_game1_BOX.dataframe
    
    print(get_schedule(2023, 1, 3).to_string())


def get_schedule(year, firstweek, lastweek):
    # List of week range. Note that lastweek is not inclusive
    weeks_list = list(range(firstweek, lastweek))

    # Instantiate schedule dataframe
    schedule_df = pd.DataFrame()

    # For each week of the season
    for w in range(len(weeks_list)):

        # Create string key in the format "Week-Year"
        date_string = str(weeks_list[w]) + '-' + str(year)

        # Create Boxscores Object for current week w     
        week_scores = Boxscores(weeks_list[w], year)       

        # Instantiate dataframe for current week w
        week_games_df = pd.DataFrame()

        # For each game data dictionary
        for g in range(len(week_scores.games[date_string])):
            
            # Create dataframe out of select game statistic keys 
            game = pd.DataFrame(week_scores.games[date_string][g], index = [0], columns=['away_name', 'away_abbr','home_name', 'home_abbr','winning_name', 'winning_abbr'])
            
            # Add week # to each index
            game['week'] = weeks_list[w]
            
            # Concat current game to list of this weeks game
            week_games_df = pd.concat([week_games_df,game])

        # Concat current game to season long dataframe
        schedule_df = pd.concat([schedule_df, week_games_df]).reset_index().drop(columns = 'index')

    return schedule_df


if __name__ == "__main__":
    try:
        main()

    except KeyboardInterrupt:
        print("Exit: Keyboard Interrupted")
        sys.exit(0)
# Out:
# Boxscore Class:
# NFL games for weeks 1, 2, 3, 4, 5, 6, 7, 8
#
# Game 0 URI:
# 202309070kan
#                away_name away_abbr              home_name home_abbr  \
# 0          Detroit Lions       det     Kansas City Chiefs       kan
# 1      Carolina Panthers       car        Atlanta Falcons       atl
# 2     Cincinnati Bengals       cin       Cleveland Browns       cle
# 3   Jacksonville Jaguars       jax     Indianapolis Colts       clt
# 4   Tampa Bay Buccaneers       tam      Minnesota Vikings       min
# 5       Tennessee Titans       oti     New Orleans Saints       nor
# 6    San Francisco 49ers       sfo    Pittsburgh Steelers       pit
# 7         Houston Texans       htx       Baltimore Ravens       rav
# 8      Arizona Cardinals       crd  Washington Commanders       was
# 9      Green Bay Packers       gnb          Chicago Bears       chi
# 10     Las Vegas Raiders       rai         Denver Broncos       den
# 11   Philadelphia Eagles       phi   New England Patriots       nwe
# 12        Miami Dolphins       mia   Los Angeles Chargers       sdg
# 13      Los Angeles Rams       ram       Seattle Seahawks       sea
# 14        Dallas Cowboys       dal        New York Giants       nyg
# 15         Buffalo Bills       buf          New York Jets       nyj
#
#              winning_name winning_abbr  week
# 0           Detroit Lions          det     1
# 1         Atlanta Falcons          atl     1
# 2        Cleveland Browns          cle     1
# 3    Jacksonville Jaguars          jax     1
# 4    Tampa Bay Buccaneers          tam     1
# 5      New Orleans Saints          nor     1
# 6     San Francisco 49ers          sfo     1
# 7        Baltimore Ravens          rav     1
# 8   Washington Commanders          was     1
# 9       Green Bay Packers          gnb     1
# 10      Las Vegas Raiders          rai     1
# 11    Philadelphia Eagles          phi     1
# 12         Miami Dolphins          mia     1
# 13       Los Angeles Rams          ram     1
# 14         Dallas Cowboys          dal     1
# 15          New York Jets          nyj     1
